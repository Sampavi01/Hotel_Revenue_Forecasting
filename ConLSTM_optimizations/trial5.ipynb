# %% [markdown]
# <a href="https://colab.research.google.com/github/Sampavi01/Hotel_Revenue_Forecasting/blob/forecasting/ConLSTM_optimizations/trial5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ConvLSTM2D, Dense, Flatten, Dropout, Input, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from datetime import timedelta
from sklearn.metrics import mean_absolute_error

# ================== CONFIG / CONSTANTS ==================
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.random.set_seed(42)
np.random.seed(42)

INPUT_FILE_NAME = 'Model_Training_Datasets.xlsx'
TEST_SET_DAYS = 60
N_TIMESTEPS = 14
TARGET_RAW_COLS = ['Revenue_By_BreakFast', 'Revenue_By_Dinner', 'Revenue_By_Lunch']

LR = 0.0005
FILTERS = 128
EPOCHS = 50
BATCH_SIZE = 16

# %%
# ================== CUSTOM LOSS FUNCTIONS ==================
def smape_loss(y_true, y_pred, eps=1e-6):
    numer = tf.abs(y_pred - y_true)
    denom = tf.abs(y_true) + tf.abs(y_pred)
    denom = tf.where(denom < eps, eps, denom)
    return tf.reduce_mean(2.0 * numer / denom)

def direction_loss(y_true, y_pred):
    """Penalizes wrong prediction direction."""
    return tf.reduce_mean(tf.abs(tf.sign(y_true * y_pred) - 1))

def ultimate_ts_loss(y_true, y_pred, alpha_mae=0.3, alpha_huber=0.3, alpha_smape=0.2, alpha_dir=0.5, delta=1.0):
    mae = tf.reduce_mean(tf.abs(y_pred - y_true))
    diff = tf.abs(y_pred - y_true)
    huber = tf.reduce_mean(tf.where(diff <= delta, 0.5 * diff**2, delta * (diff - 0.5 * delta)))
    smape_val = smape_loss(y_true, y_pred)
    dir_loss = direction_loss(y_true, y_pred)
    return (alpha_mae * mae + alpha_huber * huber + alpha_smape * smape_val + alpha_dir * dir_loss)

class UltimateTSLoss(tf.keras.losses.Loss):
    def __init__(self, alpha_mae=0.3, alpha_huber=0.3, alpha_smape=0.2, alpha_dir=0.5, delta=1.0, name="ultimate_ts_loss"):
        super().__init__(name=name)
        self.alpha_mae = alpha_mae
        self.alpha_huber = alpha_huber
        self.alpha_smape = alpha_smape
        self.alpha_dir = alpha_dir
        self.delta = delta

    def call(self, y_true, y_pred):
        return ultimate_ts_loss(
            y_true, y_pred,
            alpha_mae=self.alpha_mae,
            alpha_huber=self.alpha_huber,
            alpha_smape=self.alpha_smape,
            alpha_dir=self.alpha_dir,
            delta=self.delta
        )

    def get_config(self):
        config = super().get_config()
        config.update({
            "alpha_mae": self.alpha_mae,
            "alpha_huber": self.alpha_huber,
            "alpha_smape": self.alpha_smape,
            "alpha_dir": self.alpha_dir,
            "delta": self.delta
        })
        return config

# %%
# ================== HELPER FUNCTIONS ==================
def smape(y_true, y_pred):
    denom = (np.abs(y_true) + np.abs(y_pred)) / 2.0
    diff = np.abs(y_true - y_pred) / np.where(denom == 0, 1, denom)
    return np.mean(diff) * 100

def build_convlstm_model(n_timesteps, n_features):
    model = Sequential([
        Input(shape=(n_timesteps, 1, n_features, 1)),
        ConvLSTM2D(filters=FILTERS, kernel_size=(1, 3), padding='same',
                   return_sequences=True, activation='tanh'),
        BatchNormalization(),
        ConvLSTM2D(filters=FILTERS//2, kernel_size=(1, 3), padding='same',
                   return_sequences=False, activation='tanh'),
        BatchNormalization(),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.2),
        Dense(1)
    ])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
        loss=UltimateTSLoss(),   # <-- custom loss here
        metrics=['mae', smape_loss]
    )
    return model

def reshape_for_convlstm(X):
    return X.reshape((X.shape[0], X.shape[1], 1, X.shape[2], 1))

# %%
# ================== TRAINING LOGIC ==================
def train_and_plot_convlstm(df_center, center_name):
    df_center = df_center.sort_values('Date').reset_index(drop=True)
    for col in TARGET_RAW_COLS:
        for lag in [1, 7]:
            df_center[f'{col}_lag{lag}'] = df_center[col].shift(lag)
    df_center = df_center.fillna(0)

    max_date = df_center['Date'].max()
    test_start_date = max_date - timedelta(days=TEST_SET_DAYS)
    df_train = df_center[df_center['Date'] < test_start_date].copy()
    df_test = df_center[df_center['Date'] >= test_start_date].copy()

    feature_cols = [c for c in df_train.columns if c not in ['Date'] + TARGET_RAW_COLS]
    scaler_x = RobustScaler()
    X_train_scaled = scaler_x.fit_transform(df_train[feature_cols])
    X_test_scaled = scaler_x.transform(df_test[feature_cols])

    for target_col in TARGET_RAW_COLS:
        print(f"\n--- Training ConvLSTM for {center_name} - {target_col} ---")

        scaler_y = MinMaxScaler()
        y_train_scaled = scaler_y.fit_transform(df_train[[target_col]]).flatten()

        # Build training sequences
       # Build training sequences
        X_seq_train, y_seq_train = [], []
        for i in range(len(X_train_scaled) - N_TIMESTEPS):
            X_seq_train.append(X_train_scaled[i:i+N_TIMESTEPS])
            y_seq_train.append(y_train_scaled[i+N_TIMESTEPS])

        X_seq_train = np.array(X_seq_train)
        y_seq_train = np.array(y_seq_train)

        X_seq_train_5d = reshape_for_convlstm(X_seq_train)

        # Train model
        model = build_convlstm_model(N_TIMESTEPS, X_seq_train.shape[2])
        early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        history = model.fit(X_seq_train_5d, np.array(y_seq_train),
                            epochs=EPOCHS, batch_size=BATCH_SIZE,
                            verbose=1, validation_split=0.1,
                            callbacks=[early_stop])

        # Plot training loss
        plt.figure(figsize=(10,4))
        plt.plot(history.history['loss'], label='Train Loss')
        plt.plot(history.history['val_loss'], label='Val Loss')
        plt.title(f'Loss Convergence: {target_col}')
        plt.legend(); plt.grid(True, linestyle='--', alpha=0.5); plt.show()

        # Build test sequences
        X_combined = np.vstack([X_train_scaled[-N_TIMESTEPS:], X_test_scaled])
        X_seq_test = [X_combined[i:i+N_TIMESTEPS] for i in range(len(X_combined)-N_TIMESTEPS)]
        X_seq_test_5d = reshape_for_convlstm(np.array(X_seq_test))

        # Predict and inverse transform
        y_preds_scaled = model.predict(X_seq_test_5d).flatten()
        y_preds = scaler_y.inverse_transform(y_preds_scaled.reshape(-1,1)).flatten()

        # Align lengths
        min_len = min(len(df_test), len(y_preds))
        y_true = df_test[target_col].iloc[:min_len].values
        y_pred = y_preds[:min_len]
        dates = df_test['Date'].iloc[:min_len]

        # Plot actual vs predicted
        plt.figure(figsize=(12,5))
        plt.plot(dates, y_true, label='Actual', color='blue')
        plt.plot(dates, y_pred, label='Predicted', color='orange', linestyle='--')
        plt.title(f"{center_name} Forecast: {target_col}")
        plt.legend(); plt.show()

        # Residual plot
        residuals = y_true - y_pred
        plt.figure(figsize=(12,4))
        plt.plot(dates, residuals, marker='o', linestyle='-', alpha=0.7)
        plt.axhline(0, color='red', linestyle='--')
        plt.title(f"Residuals Over Time: {target_col}")
        plt.show()

        # Print summary metrics
        print(f"MAE: {mean_absolute_error(y_true, y_pred):.2f}")
        print(f"SMAPE: {smape(y_true, y_pred):.2f}%")

# %%
try:
    df = pd.read_excel(INPUT_FILE_NAME, sheet_name=0)
    df['Date'] = pd.to_datetime(df['Date'])
    train_and_plot_convlstm(df, "Revenue Centre 1")
except Exception as e:
    print(f"Error: {e}")
# Out:
# --- Training ConvLSTM for Revenue Centre 1 - Revenue_By_BreakFast ---
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 265ms/step - loss: 1.3290 - mae: 1.0302 - smape_loss: 1.7283 - val_loss: 0.2106 - val_mae: 0.1708 - val_smape_loss: 0.7348
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2527 - mae: 0.7519 - smape_loss: 1.7135 - val_loss: 0.9635 - val_mae: 0.2821 - val_smape_loss: 1.7296
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1489 - mae: 0.7080 - smape_loss: 1.6839 - val_loss: 0.1500 - val_mae: 0.1637 - val_smape_loss: 0.4914
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0373 - mae: 0.5552 - smape_loss: 1.6194 - val_loss: 0.1311 - val_mae: 0.1110 - val_smape_loss: 0.4576
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.6015 - mae: 0.4327 - smape_loss: 1.2912 - val_loss: 0.6414 - val_mae: 0.2117 - val_smape_loss: 1.1548
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5239 - mae: 0.1879 - smape_loss: 1.0786 - val_loss: 1.2270 - val_mae: 0.3868 - val_smape_loss: 1.8627
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2278 - mae: 0.0969 - smape_loss: 0.7873 - val_loss: 0.1195 - val_mae: 0.1178 - val_smape_loss: 0.4077
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2147 - mae: 0.0795 - smape_loss: 0.7110 - val_loss: 0.5797 - val_mae: 0.2047 - val_smape_loss: 1.2666
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1955 - mae: 0.0711 - smape_loss: 0.6784 - val_loss: 0.1658 - val_mae: 0.1434 - val_smape_loss: 0.5632
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1640 - mae: 0.0682 - smape_loss: 0.6418 - val_loss: 0.8373 - val_mae: 0.2747 - val_smape_loss: 1.4660
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1444 - mae: 0.0549 - smape_loss: 0.6004 - val_loss: 0.4835 - val_mae: 0.2093 - val_smape_loss: 1.0851
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1493 - mae: 0.0515 - smape_loss: 0.5933 - val_loss: 0.4826 - val_mae: 0.2223 - val_smape_loss: 1.1859
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1548 - mae: 0.0542 - smape_loss: 0.5973 - val_loss: 0.5489 - val_mae: 0.2527 - val_smape_loss: 1.4734
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1317 - mae: 0.0499 - smape_loss: 0.5680 - val_loss: 0.3223 - val_mae: 0.2281 - val_smape_loss: 1.2120
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1324 - mae: 0.0487 - smape_loss: 0.5716 - val_loss: 0.1306 - val_mae: 0.1177 - val_smape_loss: 0.4584
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1329 - mae: 0.0467 - smape_loss: 0.5716 - val_loss: 0.2622 - val_mae: 0.2034 - val_smape_loss: 0.9708
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1310 - mae: 0.0490 - smape_loss: 0.5643 - val_loss: 0.2955 - val_mae: 0.2205 - val_smape_loss: 1.0862
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# MAE: 899.92
# SMAPE: 70.00%
#
# --- Training ConvLSTM for Revenue Centre 1 - Revenue_By_Dinner ---
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 289ms/step - loss: 1.4455 - mae: 1.3065 - smape_loss: 1.6265 - val_loss: 0.1620 - val_mae: 0.2043 - val_smape_loss: 0.4520
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.9017 - mae: 0.7220 - smape_loss: 1.4172 - val_loss: 0.6862 - val_mae: 0.4312 - val_smape_loss: 1.5359
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5473 - mae: 0.3280 - smape_loss: 1.1049 - val_loss: 0.6118 - val_mae: 0.4112 - val_smape_loss: 1.4685
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3212 - mae: 0.2534 - smape_loss: 0.8453 - val_loss: 0.3027 - val_mae: 0.3175 - val_smape_loss: 0.9410
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3115 - mae: 0.1807 - smape_loss: 0.7859 - val_loss: 0.4062 - val_mae: 0.3862 - val_smape_loss: 1.3409
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1751 - mae: 0.1350 - smape_loss: 0.6196 - val_loss: 0.2009 - val_mae: 0.2346 - val_smape_loss: 0.5932
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1565 - mae: 0.1066 - smape_loss: 0.5537 - val_loss: 0.4646 - val_mae: 0.4100 - val_smape_loss: 1.4478
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1400 - mae: 0.1050 - smape_loss: 0.5141 - val_loss: 0.3117 - val_mae: 0.3267 - val_smape_loss: 0.9717
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1505 - mae: 0.1078 - smape_loss: 0.5293 - val_loss: 1.1704 - val_mae: 0.4963 - val_smape_loss: 1.8203
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1347 - mae: 0.1071 - smape_loss: 0.5009 - val_loss: 0.2511 - val_mae: 0.2802 - val_smape_loss: 0.7494
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1447 - mae: 0.1038 - smape_loss: 0.5173 - val_loss: 0.3135 - val_mae: 0.3297 - val_smape_loss: 0.9745
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# MAE: 1385.69
# SMAPE: 63.70%
#
# --- Training ConvLSTM for Revenue Centre 1 - Revenue_By_Lunch ---
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 17s 364ms/step - loss: 1.1953 - mae: 0.8845 - smape_loss: 1.6197 - val_loss: 0.2626 - val_mae: 0.2513 - val_smape_loss: 0.8744
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.7188 - mae: 0.3937 - smape_loss: 1.3308 - val_loss: 0.2702 - val_mae: 0.2543 - val_smape_loss: 0.8995
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.6111 - mae: 0.2327 - smape_loss: 1.2251 - val_loss: 0.8459 - val_mae: 0.3711 - val_smape_loss: 1.8563
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3023 - mae: 0.1858 - smape_loss: 0.8782 - val_loss: 0.9792 - val_mae: 0.3708 - val_smape_loss: 1.8423
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2095 - mae: 0.1190 - smape_loss: 0.7541 - val_loss: 0.6925 - val_mae: 0.3428 - val_smape_loss: 1.5170
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1792 - mae: 0.0900 - smape_loss: 0.6753 - val_loss: 0.5050 - val_mae: 0.3234 - val_smape_loss: 1.3066
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1971 - mae: 0.0903 - smape_loss: 0.6830 - val_loss: 0.2650 - val_mae: 0.2484 - val_smape_loss: 0.8781
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1708 - mae: 0.0863 - smape_loss: 0.6425 - val_loss: 0.2207 - val_mae: 0.2140 - val_smape_loss: 0.7291
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1745 - mae: 0.0907 - smape_loss: 0.6454 - val_loss: 0.2320 - val_mae: 0.2237 - val_smape_loss: 0.7655
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1854 - mae: 0.0877 - smape_loss: 0.6517 - val_loss: 0.2168 - val_mae: 0.2153 - val_smape_loss: 0.7181
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1759 - mae: 0.0883 - smape_loss: 0.6473 - val_loss: 0.1880 - val_mae: 0.1784 - val_smape_loss: 0.6280
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1704 - mae: 0.0822 - smape_loss: 0.6406 - val_loss: 0.2136 - val_mae: 0.1959 - val_smape_loss: 0.7149
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1610 - mae: 0.0783 - smape_loss: 0.6020 - val_loss: 0.2719 - val_mae: 0.2483 - val_smape_loss: 0.9299
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1613 - mae: 0.0799 - smape_loss: 0.6075 - val_loss: 0.3068 - val_mae: 0.2758 - val_smape_loss: 1.0585
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1587 - mae: 0.0764 - smape_loss: 0.5931 - val_loss: 0.2896 - val_mae: 0.2674 - val_smape_loss: 0.9786
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1602 - mae: 0.0793 - smape_loss: 0.5985 - val_loss: 0.2667 - val_mae: 0.2551 - val_smape_loss: 0.8823
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1589 - mae: 0.0763 - smape_loss: 0.5934 - val_loss: 0.2878 - val_mae: 0.2694 - val_smape_loss: 0.9572
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1589 - mae: 0.0808 - smape_loss: 0.5923 - val_loss: 0.2765 - val_mae: 0.2617 - val_smape_loss: 0.9157
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1580 - mae: 0.0772 - smape_loss: 0.5893 - val_loss: 0.2934 - val_mae: 0.2728 - val_smape_loss: 0.9775
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1571 - mae: 0.0775 - smape_loss: 0.5852 - val_loss: 0.2931 - val_mae: 0.2731 - val_smape_loss: 0.9757
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1564 - mae: 0.0799 - smape_loss: 0.5816 - val_loss: 0.2798 - val_mae: 0.2643 - val_smape_loss: 0.9274
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# MAE: 496.93
# SMAPE: 74.17%
