# %% [markdown]
# <a href="https://colab.research.google.com/github/Sampavi01/Hotel_Revenue_Forecasting/blob/forecasting/ConvLSTM_optimizations/trial3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ConvLSTM2D, Dense, Flatten, Dropout, Input, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from datetime import timedelta
from sklearn.metrics import mean_absolute_error

# ================== CONFIG / CONSTANTS ==================
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.random.set_seed(42)
np.random.seed(42)

INPUT_FILE_NAME = 'Model_Training_Datasets.xlsx'
TEST_SET_DAYS = 60
N_TIMESTEPS = 7
TARGET_RAW_COLS = ['Revenue_By_BreakFast', 'Revenue_By_Dinner', 'Revenue_By_Lunch']

LR = 0.0005
FILTERS = 64
EPOCHS = 50
BATCH_SIZE = 16

# %%
# ================== CUSTOM LOSS FUNCTIONS ==================
def smape_loss(y_true, y_pred, eps=1e-6):
    numer = tf.abs(y_pred - y_true)
    denom = tf.abs(y_true) + tf.abs(y_pred)
    denom = tf.where(denom < eps, eps, denom)
    return tf.reduce_mean(2.0 * numer / denom)

def direction_loss(y_true, y_pred):
    """Penalizes wrong prediction direction."""
    return tf.reduce_mean(tf.abs(tf.sign(y_true * y_pred) - 1))

def ultimate_ts_loss(y_true, y_pred, alpha_mae=0.3, alpha_huber=0.3, alpha_smape=0.2, alpha_dir=0.2, delta=1.0):
    mae = tf.reduce_mean(tf.abs(y_pred - y_true))
    diff = tf.abs(y_pred - y_true)
    huber = tf.reduce_mean(tf.where(diff <= delta, 0.5 * diff**2, delta * (diff - 0.5 * delta)))
    smape_val = smape_loss(y_true, y_pred)
    dir_loss = direction_loss(y_true, y_pred)
    return (alpha_mae * mae + alpha_huber * huber + alpha_smape * smape_val + alpha_dir * dir_loss)

class UltimateTSLoss(tf.keras.losses.Loss):
    def __init__(self, alpha_mae=0.3, alpha_huber=0.3, alpha_smape=0.2, alpha_dir=0.2, delta=1.0, name="ultimate_ts_loss"):
        super().__init__(name=name)
        self.alpha_mae = alpha_mae
        self.alpha_huber = alpha_huber
        self.alpha_smape = alpha_smape
        self.alpha_dir = alpha_dir
        self.delta = delta

    def call(self, y_true, y_pred):
        return ultimate_ts_loss(
            y_true, y_pred,
            alpha_mae=self.alpha_mae,
            alpha_huber=self.alpha_huber,
            alpha_smape=self.alpha_smape,
            alpha_dir=self.alpha_dir,
            delta=self.delta
        )

    def get_config(self):
        config = super().get_config()
        config.update({
            "alpha_mae": self.alpha_mae,
            "alpha_huber": self.alpha_huber,
            "alpha_smape": self.alpha_smape,
            "alpha_dir": self.alpha_dir,
            "delta": self.delta
        })
        return config

# %%
# ================== HELPER FUNCTIONS ==================
def smape(y_true, y_pred):
    denom = (np.abs(y_true) + np.abs(y_pred)) / 2.0
    diff = np.abs(y_true - y_pred) / np.where(denom == 0, 1, denom)
    return np.mean(diff) * 100

def build_convlstm_model(n_timesteps, n_features):
    model = Sequential([
        Input(shape=(n_timesteps, 1, n_features, 1)),
        ConvLSTM2D(filters=FILTERS, kernel_size=(1, 3), padding='same',
                   return_sequences=True, activation='tanh'),
        BatchNormalization(),
        ConvLSTM2D(filters=FILTERS//2, kernel_size=(1, 3), padding='same',
                   return_sequences=False, activation='tanh'),
        BatchNormalization(),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.2),
        Dense(1)
    ])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
        loss=UltimateTSLoss(),   # <-- custom loss here
        metrics=['mae', smape_loss]
    )
    return model

def reshape_for_convlstm(X):
    return X.reshape((X.shape[0], X.shape[1], 1, X.shape[2], 1))

# %%
# ================== TRAINING LOGIC ==================
def train_and_plot_convlstm(df_center, center_name):
    df_center = df_center.sort_values('Date').reset_index(drop=True)
    for col in TARGET_RAW_COLS:
        for lag in [1, 7]:
            df_center[f'{col}_lag{lag}'] = df_center[col].shift(lag)
    df_center = df_center.fillna(0)

    max_date = df_center['Date'].max()
    test_start_date = max_date - timedelta(days=TEST_SET_DAYS)
    df_train = df_center[df_center['Date'] < test_start_date].copy()
    df_test = df_center[df_center['Date'] >= test_start_date].copy()

    feature_cols = [c for c in df_train.columns if c not in ['Date'] + TARGET_RAW_COLS]
    scaler_x = RobustScaler()
    X_train_scaled = scaler_x.fit_transform(df_train[feature_cols])
    X_test_scaled = scaler_x.transform(df_test[feature_cols])

    for target_col in TARGET_RAW_COLS:
        print(f"\n--- Training ConvLSTM for {center_name} - {target_col} ---")

        scaler_y = MinMaxScaler()
        y_train_scaled = scaler_y.fit_transform(df_train[[target_col]]).flatten()

        # Build training sequences
       # Build training sequences
        X_seq_train, y_seq_train = [], []
        for i in range(len(X_train_scaled) - N_TIMESTEPS):
            X_seq_train.append(X_train_scaled[i:i+N_TIMESTEPS])
            y_seq_train.append(y_train_scaled[i+N_TIMESTEPS])

        X_seq_train = np.array(X_seq_train)
        y_seq_train = np.array(y_seq_train)

        X_seq_train_5d = reshape_for_convlstm(X_seq_train)

        # Train model
        model = build_convlstm_model(N_TIMESTEPS, X_seq_train.shape[2])
        early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        history = model.fit(X_seq_train_5d, np.array(y_seq_train),
                            epochs=EPOCHS, batch_size=BATCH_SIZE,
                            verbose=1, validation_split=0.1,
                            callbacks=[early_stop])

        # Plot training loss
        plt.figure(figsize=(10,4))
        plt.plot(history.history['loss'], label='Train Loss')
        plt.plot(history.history['val_loss'], label='Val Loss')
        plt.title(f'Loss Convergence: {target_col}')
        plt.legend(); plt.grid(True, linestyle='--', alpha=0.5); plt.show()

        # Build test sequences
        X_combined = np.vstack([X_train_scaled[-N_TIMESTEPS:], X_test_scaled])
        X_seq_test = [X_combined[i:i+N_TIMESTEPS] for i in range(len(X_combined)-N_TIMESTEPS)]
        X_seq_test_5d = reshape_for_convlstm(np.array(X_seq_test))

        # Predict and inverse transform
        y_preds_scaled = model.predict(X_seq_test_5d).flatten()
        y_preds = scaler_y.inverse_transform(y_preds_scaled.reshape(-1,1)).flatten()

        # Align lengths
        min_len = min(len(df_test), len(y_preds))
        y_true = df_test[target_col].iloc[:min_len].values
        y_pred = y_preds[:min_len]
        dates = df_test['Date'].iloc[:min_len]

        # Plot actual vs predicted
        plt.figure(figsize=(12,5))
        plt.plot(dates, y_true, label='Actual', color='blue')
        plt.plot(dates, y_pred, label='Predicted', color='orange', linestyle='--')
        plt.title(f"{center_name} Forecast: {target_col}")
        plt.legend(); plt.show()

        # Residual plot
        residuals = y_true - y_pred
        plt.figure(figsize=(12,4))
        plt.plot(dates, residuals, marker='o', linestyle='-', alpha=0.7)
        plt.axhline(0, color='red', linestyle='--')
        plt.title(f"Residuals Over Time: {target_col}")
        plt.show()

        # Print summary metrics
        print(f"MAE: {mean_absolute_error(y_true, y_pred):.2f}")
        print(f"SMAPE: {smape(y_true, y_pred):.2f}%")

# %%
try:
    df = pd.read_excel(INPUT_FILE_NAME, sheet_name=0)
    df['Date'] = pd.to_datetime(df['Date'])
    train_and_plot_convlstm(df, "Revenue Centre 1")
except Exception as e:
    print(f"Error: {e}")
# Out:
# --- Training ConvLSTM for Revenue Centre 1 - Revenue_By_BreakFast ---
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 288ms/step - loss: 0.9838 - mae: 0.9937 - smape_loss: 1.7107 - val_loss: 0.5115 - val_mae: 0.2645 - val_smape_loss: 1.5281
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.7103 - mae: 0.4683 - smape_loss: 1.6061 - val_loss: 0.4276 - val_mae: 0.2528 - val_smape_loss: 1.4054
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6311 - mae: 0.5133 - smape_loss: 1.4892 - val_loss: 0.6800 - val_mae: 0.2935 - val_smape_loss: 1.7598
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6599 - mae: 0.4003 - smape_loss: 1.5650 - val_loss: 0.1616 - val_mae: 0.1529 - val_smape_loss: 0.5498
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.5732 - mae: 0.2946 - smape_loss: 1.4583 - val_loss: 0.2333 - val_mae: 0.1910 - val_smape_loss: 0.8107
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4053 - mae: 0.2636 - smape_loss: 1.2175 - val_loss: 0.1504 - val_mae: 0.1438 - val_smape_loss: 0.5113
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3468 - mae: 0.2358 - smape_loss: 1.0883 - val_loss: 0.1404 - val_mae: 0.1414 - val_smape_loss: 0.4813
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3141 - mae: 0.1380 - smape_loss: 1.0261 - val_loss: 0.1203 - val_mae: 0.1168 - val_smape_loss: 0.4175
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2376 - mae: 0.1136 - smape_loss: 0.8501 - val_loss: 0.1196 - val_mae: 0.1195 - val_smape_loss: 0.4168
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1894 - mae: 0.0704 - smape_loss: 0.7181 - val_loss: 0.1285 - val_mae: 0.1283 - val_smape_loss: 0.4441
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1496 - mae: 0.0596 - smape_loss: 0.6361 - val_loss: 0.1508 - val_mae: 0.1409 - val_smape_loss: 0.5167
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1512 - mae: 0.0590 - smape_loss: 0.6321 - val_loss: 0.1636 - val_mae: 0.1511 - val_smape_loss: 0.5597
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1452 - mae: 0.0576 - smape_loss: 0.6138 - val_loss: 0.1726 - val_mae: 0.1586 - val_smape_loss: 0.5915
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1392 - mae: 0.0547 - smape_loss: 0.6014 - val_loss: 0.1873 - val_mae: 0.1692 - val_smape_loss: 0.6451
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1461 - mae: 0.0566 - smape_loss: 0.6097 - val_loss: 0.2160 - val_mae: 0.1834 - val_smape_loss: 0.7532
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1357 - mae: 0.0564 - smape_loss: 0.5852 - val_loss: 0.2261 - val_mae: 0.1873 - val_smape_loss: 0.7962
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1335 - mae: 0.0530 - smape_loss: 0.5770 - val_loss: 0.2343 - val_mae: 0.1906 - val_smape_loss: 0.8305
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1313 - mae: 0.0533 - smape_loss: 0.5686 - val_loss: 0.2415 - val_mae: 0.1944 - val_smape_loss: 0.8592
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1309 - mae: 0.0523 - smape_loss: 0.5667 - val_loss: 0.2532 - val_mae: 0.2003 - val_smape_loss: 0.9101
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# MAE: 808.94
# SMAPE: 77.43%
#
# --- Training ConvLSTM for Revenue Centre 1 - Revenue_By_Dinner ---
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 14s 283ms/step - loss: 1.0551 - mae: 1.1281 - smape_loss: 1.5897 - val_loss: 0.9331 - val_mae: 0.5015 - val_smape_loss: 1.9939
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8444 - mae: 0.9716 - smape_loss: 1.4207 - val_loss: 0.9881 - val_mae: 0.5384 - val_smape_loss: 1.9946
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5990 - mae: 0.5325 - smape_loss: 1.2442 - val_loss: 1.0319 - val_mae: 0.5886 - val_smape_loss: 2.0000
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4985 - mae: 0.4439 - smape_loss: 1.1665 - val_loss: 0.5358 - val_mae: 0.4330 - val_smape_loss: 1.5536
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4491 - mae: 0.3374 - smape_loss: 1.0732 - val_loss: 0.4037 - val_mae: 0.3896 - val_smape_loss: 1.2858
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3321 - mae: 0.2519 - smape_loss: 0.9202 - val_loss: 0.9442 - val_mae: 0.5157 - val_smape_loss: 1.9708
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2613 - mae: 0.1954 - smape_loss: 0.7947 - val_loss: 0.8395 - val_mae: 0.4929 - val_smape_loss: 1.9320
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2332 - mae: 0.1779 - smape_loss: 0.7385 - val_loss: 0.8984 - val_mae: 0.5280 - val_smape_loss: 1.9556
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2174 - mae: 0.1549 - smape_loss: 0.7025 - val_loss: 0.6377 - val_mae: 0.4574 - val_smape_loss: 1.7746
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1974 - mae: 0.1296 - smape_loss: 0.6572 - val_loss: 0.4208 - val_mae: 0.3978 - val_smape_loss: 1.4032
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1588 - mae: 0.1201 - smape_loss: 0.5742 - val_loss: 0.3775 - val_mae: 0.3719 - val_smape_loss: 1.2211
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1441 - mae: 0.1090 - smape_loss: 0.5286 - val_loss: 0.3041 - val_mae: 0.3207 - val_smape_loss: 0.9502
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1429 - mae: 0.0937 - smape_loss: 0.5174 - val_loss: 0.2686 - val_mae: 0.2940 - val_smape_loss: 0.8193
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1356 - mae: 0.1007 - smape_loss: 0.5038 - val_loss: 0.2248 - val_mae: 0.2567 - val_smape_loss: 0.6680
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1255 - mae: 0.0918 - smape_loss: 0.4651 - val_loss: 0.2520 - val_mae: 0.2793 - val_smape_loss: 0.7561
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1277 - mae: 0.0989 - smape_loss: 0.4747 - val_loss: 0.2811 - val_mae: 0.3036 - val_smape_loss: 0.8543
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1280 - mae: 0.0928 - smape_loss: 0.4767 - val_loss: 0.2553 - val_mae: 0.2820 - val_smape_loss: 0.7602
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1234 - mae: 0.0906 - smape_loss: 0.4565 - val_loss: 0.2633 - val_mae: 0.2883 - val_smape_loss: 0.7864
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1208 - mae: 0.0912 - smape_loss: 0.4482 - val_loss: 0.2537 - val_mae: 0.2805 - val_smape_loss: 0.7521
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1190 - mae: 0.0842 - smape_loss: 0.4410 - val_loss: 0.2532 - val_mae: 0.2804 - val_smape_loss: 0.7533
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1192 - mae: 0.0899 - smape_loss: 0.4420 - val_loss: 0.2525 - val_mae: 0.2802 - val_smape_loss: 0.7554
# Epoch 22/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1182 - mae: 0.0897 - smape_loss: 0.4376 - val_loss: 0.2522 - val_mae: 0.2804 - val_smape_loss: 0.7570
# Epoch 23/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1171 - mae: 0.0889 - smape_loss: 0.4339 - val_loss: 0.2541 - val_mae: 0.2818 - val_smape_loss: 0.7658
# Epoch 24/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1170 - mae: 0.0907 - smape_loss: 0.4334 - val_loss: 0.2580 - val_mae: 0.2851 - val_smape_loss: 0.7820
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# MAE: 1339.60
# SMAPE: 54.21%
#
# --- Training ConvLSTM for Revenue Centre 1 - Revenue_By_Lunch ---
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 266ms/step - loss: 0.9295 - mae: 0.8240 - smape_loss: 1.6539 - val_loss: 0.6719 - val_mae: 0.3700 - val_smape_loss: 1.8681
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.7062 - mae: 0.5615 - smape_loss: 1.5275 - val_loss: 0.8038 - val_mae: 0.3923 - val_smape_loss: 1.9081
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6091 - mae: 0.4216 - smape_loss: 1.4346 - val_loss: 0.8472 - val_mae: 0.4052 - val_smape_loss: 1.9519
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5654 - mae: 0.3257 - smape_loss: 1.3866 - val_loss: 0.9859 - val_mae: 0.4795 - val_smape_loss: 2.0000
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5211 - mae: 0.3038 - smape_loss: 1.3148 - val_loss: 0.4124 - val_mae: 0.3176 - val_smape_loss: 1.3081
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3901 - mae: 0.2931 - smape_loss: 1.1269 - val_loss: 0.1979 - val_mae: 0.2101 - val_smape_loss: 0.6560
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3328 - mae: 0.2020 - smape_loss: 1.0159 - val_loss: 0.4153 - val_mae: 0.3103 - val_smape_loss: 1.2702
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2301 - mae: 0.1200 - smape_loss: 0.8196 - val_loss: 0.4104 - val_mae: 0.3125 - val_smape_loss: 1.2762
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1982 - mae: 0.1280 - smape_loss: 0.7544 - val_loss: 0.2855 - val_mae: 0.2697 - val_smape_loss: 0.9440
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1830 - mae: 0.0993 - smape_loss: 0.7118 - val_loss: 0.2550 - val_mae: 0.2526 - val_smape_loss: 0.8381
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1653 - mae: 0.0872 - smape_loss: 0.6629 - val_loss: 0.2827 - val_mae: 0.2684 - val_smape_loss: 0.9326
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1676 - mae: 0.0847 - smape_loss: 0.6583 - val_loss: 0.2569 - val_mae: 0.2493 - val_smape_loss: 0.8449
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1570 - mae: 0.0788 - smape_loss: 0.6319 - val_loss: 0.2621 - val_mae: 0.2505 - val_smape_loss: 0.8610
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1635 - mae: 0.0840 - smape_loss: 0.6354 - val_loss: 0.2561 - val_mae: 0.2460 - val_smape_loss: 0.8419
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1506 - mae: 0.0798 - smape_loss: 0.6096 - val_loss: 0.2641 - val_mae: 0.2488 - val_smape_loss: 0.8690
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1577 - mae: 0.0790 - smape_loss: 0.6180 - val_loss: 0.2831 - val_mae: 0.2636 - val_smape_loss: 0.9366
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# MAE: 535.76
# SMAPE: 102.57%
