# %% [markdown]
# <a href="https://colab.research.google.com/github/Sampavi01/Hotel_Revenue_Forecasting/blob/forecasting/ConvLSTM_optimizations/TRIAL2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ConvLSTM2D, Dense, Flatten, Dropout, Input, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from datetime import timedelta
from sklearn.metrics import mean_absolute_error

# ================== CONFIG / CONSTANTS ==================
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.random.set_seed(42)
np.random.seed(42)

INPUT_FILE_NAME = 'Model_Training_Datasets.xlsx'
TEST_SET_DAYS = 60
N_TIMESTEPS = 7
TARGET_RAW_COLS = ['Revenue_By_BreakFast', 'Revenue_By_Dinner', 'Revenue_By_Lunch']

LR = 0.005
FILTERS = 64
EPOCHS = 50
BATCH_SIZE = 16

# %%
# ================== CUSTOM LOSS FUNCTIONS ==================
def smape_loss(y_true, y_pred, eps=1e-6):
    numer = tf.abs(y_pred - y_true)
    denom = tf.abs(y_true) + tf.abs(y_pred)
    denom = tf.where(denom < eps, eps, denom)
    return tf.reduce_mean(2.0 * numer / denom)

def direction_loss(y_true, y_pred):
    """Penalizes wrong prediction direction."""
    return tf.reduce_mean(tf.abs(tf.sign(y_true * y_pred) - 1))

def ultimate_ts_loss(y_true, y_pred, alpha_mae=0.3, alpha_huber=0.3, alpha_smape=0.2, alpha_dir=0.2, delta=1.0):
    mae = tf.reduce_mean(tf.abs(y_pred - y_true))
    diff = tf.abs(y_pred - y_true)
    huber = tf.reduce_mean(tf.where(diff <= delta, 0.5 * diff**2, delta * (diff - 0.5 * delta)))
    smape_val = smape_loss(y_true, y_pred)
    dir_loss = direction_loss(y_true, y_pred)
    return (alpha_mae * mae + alpha_huber * huber + alpha_smape * smape_val + alpha_dir * dir_loss)

class UltimateTSLoss(tf.keras.losses.Loss):
    def __init__(self, alpha_mae=0.3, alpha_huber=0.3, alpha_smape=0.2, alpha_dir=0.2, delta=1.0, name="ultimate_ts_loss"):
        super().__init__(name=name)
        self.alpha_mae = alpha_mae
        self.alpha_huber = alpha_huber
        self.alpha_smape = alpha_smape
        self.alpha_dir = alpha_dir
        self.delta = delta

    def call(self, y_true, y_pred):
        return ultimate_ts_loss(
            y_true, y_pred,
            alpha_mae=self.alpha_mae,
            alpha_huber=self.alpha_huber,
            alpha_smape=self.alpha_smape,
            alpha_dir=self.alpha_dir,
            delta=self.delta
        )

    def get_config(self):
        config = super().get_config()
        config.update({
            "alpha_mae": self.alpha_mae,
            "alpha_huber": self.alpha_huber,
            "alpha_smape": self.alpha_smape,
            "alpha_dir": self.alpha_dir,
            "delta": self.delta
        })
        return config

# %%
# ================== HELPER FUNCTIONS ==================
def smape(y_true, y_pred):
    denom = (np.abs(y_true) + np.abs(y_pred)) / 2.0
    diff = np.abs(y_true - y_pred) / np.where(denom == 0, 1, denom)
    return np.mean(diff) * 100

def build_convlstm_model(n_timesteps, n_features):
    model = Sequential([
        Input(shape=(n_timesteps, 1, n_features, 1)),
        ConvLSTM2D(filters=FILTERS, kernel_size=(1, 3), padding='same',
                   return_sequences=True, activation='tanh'),
        BatchNormalization(),
        ConvLSTM2D(filters=FILTERS//2, kernel_size=(1, 3), padding='same',
                   return_sequences=False, activation='tanh'),
        BatchNormalization(),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.2),
        Dense(1)
    ])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
        loss=UltimateTSLoss(),   # <-- custom loss here
        metrics=['mae', smape_loss]
    )
    return model

def reshape_for_convlstm(X):
    return X.reshape((X.shape[0], X.shape[1], 1, X.shape[2], 1))

# %%
# ================== TRAINING LOGIC ==================
def train_and_plot_convlstm(df_center, center_name):
    df_center = df_center.sort_values('Date').reset_index(drop=True)
    for col in TARGET_RAW_COLS:
        for lag in [1, 7]:
            df_center[f'{col}_lag{lag}'] = df_center[col].shift(lag)
    df_center = df_center.fillna(0)

    max_date = df_center['Date'].max()
    test_start_date = max_date - timedelta(days=TEST_SET_DAYS)
    df_train = df_center[df_center['Date'] < test_start_date].copy()
    df_test = df_center[df_center['Date'] >= test_start_date].copy()

    feature_cols = [c for c in df_train.columns if c not in ['Date'] + TARGET_RAW_COLS]
    scaler_x = RobustScaler()
    X_train_scaled = scaler_x.fit_transform(df_train[feature_cols])
    X_test_scaled = scaler_x.transform(df_test[feature_cols])

    for target_col in TARGET_RAW_COLS:
        print(f"\n--- Training ConvLSTM for {center_name} - {target_col} ---")

        scaler_y = MinMaxScaler()
        y_train_scaled = scaler_y.fit_transform(df_train[[target_col]]).flatten()

        # Build training sequences
       # Build training sequences
        X_seq_train, y_seq_train = [], []
        for i in range(len(X_train_scaled) - N_TIMESTEPS):
            X_seq_train.append(X_train_scaled[i:i+N_TIMESTEPS])
            y_seq_train.append(y_train_scaled[i+N_TIMESTEPS])

        X_seq_train = np.array(X_seq_train)
        y_seq_train = np.array(y_seq_train)

        X_seq_train_5d = reshape_for_convlstm(X_seq_train)

        # Train model
        model = build_convlstm_model(N_TIMESTEPS, X_seq_train.shape[2])
        early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        history = model.fit(X_seq_train_5d, np.array(y_seq_train),
                            epochs=EPOCHS, batch_size=BATCH_SIZE,
                            verbose=1, validation_split=0.1,
                            callbacks=[early_stop])

        # Plot training loss
        plt.figure(figsize=(10,4))
        plt.plot(history.history['loss'], label='Train Loss')
        plt.plot(history.history['val_loss'], label='Val Loss')
        plt.title(f'Loss Convergence: {target_col}')
        plt.legend(); plt.grid(True, linestyle='--', alpha=0.5); plt.show()

        # Build test sequences
        X_combined = np.vstack([X_train_scaled[-N_TIMESTEPS:], X_test_scaled])
        X_seq_test = [X_combined[i:i+N_TIMESTEPS] for i in range(len(X_combined)-N_TIMESTEPS)]
        X_seq_test_5d = reshape_for_convlstm(np.array(X_seq_test))

        # Predict and inverse transform
        y_preds_scaled = model.predict(X_seq_test_5d).flatten()
        y_preds = scaler_y.inverse_transform(y_preds_scaled.reshape(-1,1)).flatten()

        # Align lengths
        min_len = min(len(df_test), len(y_preds))
        y_true = df_test[target_col].iloc[:min_len].values
        y_pred = y_preds[:min_len]
        dates = df_test['Date'].iloc[:min_len]

        # Plot actual vs predicted
        plt.figure(figsize=(12,5))
        plt.plot(dates, y_true, label='Actual', color='blue')
        plt.plot(dates, y_pred, label='Predicted', color='orange', linestyle='--')
        plt.title(f"{center_name} Forecast: {target_col}")
        plt.legend(); plt.show()

        # Residual plot
        residuals = y_true - y_pred
        plt.figure(figsize=(12,4))
        plt.plot(dates, residuals, marker='o', linestyle='-', alpha=0.7)
        plt.axhline(0, color='red', linestyle='--')
        plt.title(f"Residuals Over Time: {target_col}")
        plt.show()

        # Print summary metrics
        print(f"MAE: {mean_absolute_error(y_true, y_pred):.2f}")
        print(f"SMAPE: {smape(y_true, y_pred):.2f}%")

# %%
try:
    df = pd.read_excel(INPUT_FILE_NAME, sheet_name=0)
    df['Date'] = pd.to_datetime(df['Date'])
    train_and_plot_convlstm(df, "Revenue Centre 1")
except Exception as e:
    print(f"Error: {e}")
# Out:
# --- Training ConvLSTM for Revenue Centre 1 - Revenue_By_BreakFast ---
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 14s 271ms/step - loss: 1.1106 - mae: 1.1790 - smape_loss: 1.6625 - val_loss: 0.4363 - val_mae: 0.2519 - val_smape_loss: 1.4014
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5642 - mae: 0.4278 - smape_loss: 1.3942 - val_loss: 0.1360 - val_mae: 0.1383 - val_smape_loss: 0.4647
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2090 - mae: 0.0920 - smape_loss: 0.7595 - val_loss: 0.1417 - val_mae: 0.1416 - val_smape_loss: 0.4900
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1376 - mae: 0.0536 - smape_loss: 0.5838 - val_loss: 0.1862 - val_mae: 0.1685 - val_smape_loss: 0.6497
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1326 - mae: 0.0522 - smape_loss: 0.5737 - val_loss: 0.2039 - val_mae: 0.1774 - val_smape_loss: 0.7144
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1319 - mae: 0.0523 - smape_loss: 0.5715 - val_loss: 0.2279 - val_mae: 0.1884 - val_smape_loss: 0.8063
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1315 - mae: 0.0521 - smape_loss: 0.5699 - val_loss: 0.2518 - val_mae: 0.1984 - val_smape_loss: 0.8974
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1309 - mae: 0.0524 - smape_loss: 0.5671 - val_loss: 0.2592 - val_mae: 0.2021 - val_smape_loss: 0.9291
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1310 - mae: 0.0522 - smape_loss: 0.5677 - val_loss: 0.2753 - val_mae: 0.2108 - val_smape_loss: 0.9958
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1313 - mae: 0.0525 - smape_loss: 0.5688 - val_loss: 0.2851 - val_mae: 0.2156 - val_smape_loss: 1.0391
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1311 - mae: 0.0525 - smape_loss: 0.5680 - val_loss: 0.2796 - val_mae: 0.2131 - val_smape_loss: 1.0159
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1310 - mae: 0.0523 - smape_loss: 0.5675 - val_loss: 0.2939 - val_mae: 0.2197 - val_smape_loss: 1.0719
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# MAE: 1296.46
# SMAPE: 86.36%
#
# --- Training ConvLSTM for Revenue Centre 1 - Revenue_By_Dinner ---
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 14s 262ms/step - loss: 1.3876 - mae: 1.6703 - smape_loss: 1.6291 - val_loss: 0.1163 - val_mae: 0.1650 - val_smape_loss: 0.3233
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5108 - mae: 0.4805 - smape_loss: 1.1072 - val_loss: 0.2006 - val_mae: 0.2327 - val_smape_loss: 0.5802
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1514 - mae: 0.1247 - smape_loss: 0.5512 - val_loss: 0.2881 - val_mae: 0.3105 - val_smape_loss: 0.8808
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1192 - mae: 0.0908 - smape_loss: 0.4405 - val_loss: 0.2872 - val_mae: 0.3100 - val_smape_loss: 0.8808
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1184 - mae: 0.0904 - smape_loss: 0.4317 - val_loss: 0.2962 - val_mae: 0.3170 - val_smape_loss: 0.9123
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1155 - mae: 0.0901 - smape_loss: 0.4274 - val_loss: 0.2783 - val_mae: 0.3032 - val_smape_loss: 0.8492
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1144 - mae: 0.0887 - smape_loss: 0.4238 - val_loss: 0.2741 - val_mae: 0.2999 - val_smape_loss: 0.8348
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1140 - mae: 0.0886 - smape_loss: 0.4223 - val_loss: 0.2744 - val_mae: 0.3001 - val_smape_loss: 0.8357
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1140 - mae: 0.0886 - smape_loss: 0.4222 - val_loss: 0.2743 - val_mae: 0.3001 - val_smape_loss: 0.8355
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1140 - mae: 0.0888 - smape_loss: 0.4220 - val_loss: 0.2737 - val_mae: 0.2995 - val_smape_loss: 0.8333
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1139 - mae: 0.0889 - smape_loss: 0.4218 - val_loss: 0.2744 - val_mae: 0.3001 - val_smape_loss: 0.8358
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# MAE: 2045.69
# SMAPE: 73.00%
#
# --- Training ConvLSTM for Revenue Centre 1 - Revenue_By_Lunch ---
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 286ms/step - loss: 1.4639 - mae: 1.7834 - smape_loss: 1.7324 - val_loss: 0.3120 - val_mae: 0.2399 - val_smape_loss: 0.8549
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.7277 - mae: 0.6773 - smape_loss: 1.4676 - val_loss: 0.2489 - val_mae: 0.2421 - val_smape_loss: 0.8185
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2261 - mae: 0.1282 - smape_loss: 0.8030 - val_loss: 0.2099 - val_mae: 0.2135 - val_smape_loss: 0.6979
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1709 - mae: 0.0796 - smape_loss: 0.6487 - val_loss: 0.2399 - val_mae: 0.2332 - val_smape_loss: 0.7925
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1506 - mae: 0.0766 - smape_loss: 0.6064 - val_loss: 0.2507 - val_mae: 0.2406 - val_smape_loss: 0.8282
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1444 - mae: 0.0737 - smape_loss: 0.5873 - val_loss: 0.2528 - val_mae: 0.2452 - val_smape_loss: 0.8357
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1442 - mae: 0.0737 - smape_loss: 0.5863 - val_loss: 0.2653 - val_mae: 0.2544 - val_smape_loss: 0.8777
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1434 - mae: 0.0727 - smape_loss: 0.5835 - val_loss: 0.2655 - val_mae: 0.2543 - val_smape_loss: 0.8772
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1442 - mae: 0.0742 - smape_loss: 0.5867 - val_loss: 0.2646 - val_mae: 0.2538 - val_smape_loss: 0.8759
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1435 - mae: 0.0712 - smape_loss: 0.5835 - val_loss: 0.2667 - val_mae: 0.2557 - val_smape_loss: 0.8809
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1437 - mae: 0.0722 - smape_loss: 0.5844 - val_loss: 0.2710 - val_mae: 0.2584 - val_smape_loss: 0.8953
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1434 - mae: 0.0717 - smape_loss: 0.5833 - val_loss: 0.2722 - val_mae: 0.2583 - val_smape_loss: 0.8986
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1439 - mae: 0.0732 - smape_loss: 0.5852 - val_loss: 0.2726 - val_mae: 0.2591 - val_smape_loss: 0.8999
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# MAE: 437.42
# SMAPE: 80.40%
